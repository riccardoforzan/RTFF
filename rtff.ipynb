    "/media/manuel/Tesi/Datasets/dataset-80848/r6sk-x3g9.rdf",
    "/media/manuel/Tesi/Datasets/dataset-88131/v9dk-xgzr.rdf",
]

# %%
from lxml import etree


def parse_as_XML(file_path: str):
    classes = list()
    entities = list()
    literals = list()
    properties = list()


    parser = etree.XMLParser(recover=True)
    try:
        tree = etree.parse(file_path, parser)

        root = tree.getroot()

        if root == None:
            raise Exception("File cannot be parsed as XML")
        
        for element in root.iter():
            #print("Tag:" + str(element.tag) + " Text:" + str(element.text))
            
            if "Description" in element.tag:
                if len(element.attrib.keys()) > 0:
                    if "about" in element.attrib.keys()[0]:
                        entities.append(element.get(element.attrib.keys()[0]))
            
            elif "type" in element.tag:
                if len(element.attrib.keys()) > 0:
                    if "resource" in element.attrib.keys()[0]:
                        classes.append(element.get(element.attrib.keys()[0]))

            elif "}" in element.tag:
                split = element.tag.split("}")
                property = split[1]
                if property != "RDF" and property != "Description":
                    properties.append(property)
            else:
                properties.append(element.tag)

            if element.text != None and element.text.strip():
                literals.append(element.text)

        


        for c in classes:
            print(c)
        for c in entities:
            print(c)
        for c in properties:
            print(c)
        for c in literals:
            print(c)


    except Exception as e:
        print(f"{file_path} Exception: {str(e)}")

# %%
parse_as_XML("/media/manuel/Tesi/Datasets/dataset-2556/rows.rdf")
# Out:
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# phone_number
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ds::-computed_region_ciix_jbrk
# ds::-computed_region_i25a_xk5b
# _6x9d-idz4
# rowID
# member
# full_library_name
# address
# county
# mailing_address
# phone_number
# fax_number
# email_address
# document
# library_system_membership
# geo_address
# full_address
# ds::-computed_region_7u8j_y3re
# ...
# POINT (-123.919146 45.993129)
# 32
# 16
# 2318
# row-ytf6~rjem~cix8
# Lake County Library - Christmas Valley Branch Library
# 57334 Christmas Tree Lane, Christmas Valley, OR 97641
# Lake
# Public
# PO Box 87, Christmas Valley, OR 97641
# (541) 576-2336
# (541) 576-2336
# juliec@lakecountylibrary.org
# NONE
# POINT (-120.680976 43.239679)
# POINT (-120.680976 43.239679)
# 55
# 28
# 2370
# row-tmxx_x29g.c763
# Coquille Public Library
# 105 N Birch St, Coquille, OR 97423
# Coos
# Public
# 105 N Birch St, Coquille, OR 97423
# (541) 396-2166
# ssands@coastlinelibrarynetwork.org
# CCLSD
# POINT (-124.190756 43.175541)
# POINT (-124.190756 43.175541)
# 1
# 1
# 2320
# row-pqy7-q5ca_r7j8
# Newport Public Library
# 35 NW Nye St, Newport, OR 97365
# Lincoln
# Public
# 35 NW Nye St, Newport, OR 97365
# (541) 265-2153
# reference@newportlibrary.org
# LCLD
# POINT (-124.055643 44.636986)
# POINT (-124.055643 44.636986)
# 10
# 5
# 2372
# row-h3cq_8wp2-guqa
# Stayton Public Library
# 515 N First Ave, Stayton, OR 97383
# Marion
# Public
# 515 N First Ave, Stayton, OR 97383
# (503) 769-3313
# (503) 769-3218
# staytonpl@ccrls.org
# CCRLS
# POINT (-122.794371 44.799125)
# POINT (-122.794371 44.799125)
# 17
# 9
# 2409
# row-cqbh~x4pm~sv9y
# Woodburn Public Library
# 280 Garfield St, Woodburn, OR 97071
# Marion
# Public
# 280 Garfield St, Woodburn, OR 97071
# (503) 982-5262
# (503) 982-5258
# reference@ci.woodburn.or.us
# CCRLS
# POINT (-122.857981 45.143026)
# POINT (-122.857981 45.143026)
# 22
# 11
# 2409
# row-5a24.isez-ismv
# Process Work Institute - GRADUATE SCHOOL
# 2049 NW Hoyt St, Portland, OR 97209
# Academic
# 503-223-8188
# 503-227-7003
# POINT (-122.69353 45.527034)
# POINT (-122.69353 45.527034)
# 36
# 18
# 2410
# row-kjwh_jt9t~q2rz
# Multnomah County Library - Albina Library
# 3605 NE 15th Ave, Portland, OR 97212
# Multnomah
# Public
# 503-988-5123
# NONE
# POINT (-122.650397 45.548892)
# POINT (-122.650397 45.548892)
# 43
# 22
# 2410
# row-ktai.gi5y~t7kq
# Amity Public Library
# 307 S Trade St, Amity, OR 97101
# Yamhill
# Public
# PO Box 470, Amity, OR 97101
# (503) 835-8181
# CCRLS
# POINT (-123.206208 45.117191)
# POINT (-123.206208 45.117191)
# 23
# 12
# 2453
# row-v75n.bk3j_iazu
# Oregon College Of Oriental Medicine
# 75 NW Couch Street, Portland, OR 97209
# Multnomah
# Academic
# 503-253-3443 x 132
# librarian@ocom.edu
# POINT (-122.671064 45.523872)
# POINT (-122.671064 45.523872)
# 36
# 18
# 2410
# row-sr2r-m28k.maze
# Enterprise Public Library
# 101 NE First St, Enterprise, OR 97828
# Wallowa
# Public
# 101 NE First St, Enterprise, OR 97828
# (541) 426-3906
# (541) 426-3395
# enterpl@eoni.com
# NONE
# POINT (-117.276305 45.425804)
# POINT (-117.276305 45.425804)
# 58
# 29
# 2450
# row-94ju-g2kv.4scj
# Klamath County Library Service District
# 126 S Third St, Klamath Falls, OR 97601
# Klamath
# Public
# 126 S Third St, Klamath Falls, OR 97601
# (541) 882-8895
# (541) 882-6166
# NONE
# POINT (-121.784577 42.222545)
# POINT (-121.784577 42.222545)
# 56
# 28
# 2369
# row-8fbw-3s64_3xbm
# Mt. Angel Public Library
# 290 E. Charles St, Mt. Angel, OR 97362
# Marion
# Public
# PO Box 870, Mt. Angel, OR 97362
# (503) 845-6401
# library.mountangel@ccrls.org
# CCRLS
# POINT (-122.797871 45.067809)
# POINT (-122.797871 45.067809)
# 18
# 9
# 2409
# row-fxtm-85b3-w54e
# Multnomah County Library - Kenton Library
# 8226 N. Denver Ave, Portland, OR 97217
# Multnomah
# Public
# 8226 N. Denver Ave, Portland, OR 97217
# (503) 988-5123
# (503) 988-5441
# NONE
# POINT (-122.686888 45.582892)
# POINT (-122.686888 45.582892)
# 44
# 22
# 2410
# row-vdbh~he6x~hyaw
# Hood River County Library District
# 502 State St, Hood River, OR 97031
# Hood River
# Public
# 502 State St, Hood River, OR 97031
# 541-386-2535
# info@hoodriverlibrary.org
# NONE
# POINT (-121.515597 45.708179)
# POINT (-121.515597 45.708179)
# 52
# 26
# 2366
# row-4znn.q9qk.a6ik
# Jackson County Library Services - Central Point Branch Library
# 116 South Third Street, Central Point, OR 97502
# Jackson
# Public
# (541) 664-3228
# info@jcls.org
# NONE
# POINT (-122.914071 42.37382)
# POINT (-122.914071 42.37382)
# 4
# 2
# 2367
# row-grbj-kvtm.m5c9
# F. Maxine and Thomas W. Cook Memorial Library
# 2006 4th Street, La Grande, OR 97850
# Union
# Public
# 2006 4th Street, La Grande, OR 97850
# (541) 962-1339
# cbushman@cookmemoriallibrary.org
# NONE
# POINT (-118.096407 45.330328)
# POINT (-118.096407 45.330328)
# 58
# 29
# 2414
# row-q4gx.g8b8_3qdb
# Vernonia Public Library
# 701 Weed Ave, Vernonia, OR 97064
# Columbia
# Public
# 701 Weed Ave, Vernonia, OR 97064
# (503) 429-1818
# (503) 429-0729
# library@vernonia-or.gov
# NONE
# POINT (-123.19649 45.858083)
# POINT (-123.19649 45.858083)
# 31
# 16
# 2319
# row-bp7y-gmu5.9zbu
# Clackamas Community College Library
# 19600 Molalla Ave, Oregon City, OR 97045-7998
# Clackamas
# Academic
# 503-594-6323
# 503-655-8925
# reference@clackamas.edu
# POINT (-122.579593 45.323744)
# POINT (-122.579593 45.323744)
# 40
# 20
# 2317
# row-hnhs-8eym_ig28
# Eastern Oregon University Library
# 1 University Blvd, La Grande, OR 97850-2899
# Union
# Academic
# 1 University Boulevard, OR
# 541-962-3792
# POINT (-118.093198 45.321201)
# POINT (-118.093198 45.321201)
# 58
# 29
# 2414
# row-h962~kwxh_xm4u
# Oregon OSHA Resource Center
# 350 Winter St NE, Room 26, Salem, OR 97301
# Marion
# Special
# 350 Winter St NE, Salem, OR 97301
# 1-800-922-2689
# (503) 947-7463
# osha.resource@state.or.us
# POINT (-123.030838 44.94127)
# POINT (-123.030838 44.94127)
# 21
# 11
# 2409
# row-sgkq~fhfu~5y9h
# Leaburg Library
# 42888 McKenzie Hwy, Walterville, OR 97489
# Lane
# Volunteer
# PO Box 267, Walterville, OR 97489
# (541) 896-3112
# POINT (-122.675605 44.107185)
# POINT (-122.675605 44.107185)
# 11
# 6
# 2371
# row-jtzv_64uf~9t2f
# Corvallis-Benton County Public Library
# 645 NW Monroe Ave, Corvallis, OR 97330
# Benton
# Public
# 645 NW Monroe Ave, Corvallis, OR 97330
# (541) 766-6928
# (541) 766-6915
# NONE
# POINT (-123.264563 44.56527)
# POINT (-123.264563 44.56527)
# 16
# 8
# 2316
# row-im6b.hka7.rgr8
# Cornelius Public Library
# 1370 N Adair St, Cornelius, OR 97113
# Washington
# Public
# 1355 N Barlow St, Cornelius, OR 97113
# (503) 357-4093
# (503) 357-7775
# library@ci.cornelius.or.us
# WCCLS
# POINT (-123.055217 45.52092)
# POINT (-123.055217 45.52092)
# 29
# 15
# 724
# row-8izp_refd~mxab
# Willamette University - J. W. Long Law Library
# 245 Winter St SE, Salem, OR 97301-3916
# Marion
# Academic
# 245 Winter St SE, Salem, OR 97301-3916
# 503-370-6386
# 503-375-5426
# POINT (-123.033818 44.935336)
# POINT (-123.033818 44.935336)
# 21
# 11
# 2409
# row-vjqp.wn7a_e92g
# Hillsboro Public Library - Brookwood Library
# 2850 NE Brookwood Parkway, Hillsboro, OR 97124
# Washington
# Public
# 2850 NE Brookwood Parkway, Hillsboro, OR 97124
# (503) 615-6500
# (503) 615-6601
# WCCLS
# POINT (-122.93698 45.543238)
# POINT (-122.93698 45.543238)
# 30
# 15
# 724
# row-mtqs~2yfn~dqd9
# Milton-Freewater Public Library
# 8 SW Eighth Ave, Milton-Freewater, OR 97862-1501
# Umatilla
# Public
# 8 SW Eighth Ave, Milton-Freewater, OR 97862-1501
# (541) 938-8247
# (541) 938-8254
# librarycirculation@milton-freewater-or.gov
# UCSLD
# POINT (-118.385336 45.927644)
# POINT (-118.385336 45.927644)
# 57
# 29
# 2413
# row-am6f.a4ew.cq9v
# Rainier City Library
# 106 B St, Rainier, OR 97048
# Columbia
# Public
# PO Box 100, Rainier, OR 97048
# (503) 556-7301
# (503) 556-3200
# NONE
# POINT (-122.855747 45.140077)
# POINT (-122.855747 45.140077)
# 22
# 11
# 2409
# row-sirf.n89j~p9en
# Scappoose Public Library
# 52469 SE 2nd St, Scappoose, OR 97056
# Columbia
# Public
# PO Box 400, Scappoose, OR 97056
# (503) 543-7123
# (503) 543-7161
# scappl@scappooselibrary.org
# NONE
# POINT (-122.876321 45.756581)
# POINT (-122.876321 45.756581)
# 31
# 16
# 2319
# row-wch2_hb9q~ua9k
# Deschutes Public Library District
# 507 NW Wall St, Bend, OR 97703
# Deschutes
# Public
# 507 NW Wall St, Bend, OR 97703
# (541) 312-1020
# (541) 389-2982
# NONE
# POINT (-121.317282 44.056159)
# POINT (-121.317282 44.056159)
# 54
# 27
# 2362
# row-tghz~awxd~ejin
# Portland Community College - Sylvania Campus
# 12000 SW 49th Ave, Portland, OR 97219-7199
# Academic
# PO Box 19000, Portland, OR 97280-0990
# 971-722-4935
# 971 722--4977
# https://www.pcc.edu/library/about/people/contact/email-a-librarian/
# POINT (-122.727122 45.439574)
# POINT (-122.727122 45.439574)
# 35
# 18
# 2410
# row-2ycr-dtu8-ej6b
# Linn County Law Library
# 304 Broadalbin St SW, Albany, OR 97321
# Linn
# Special
# 304 Broadalbin St SW, Albany, OR 97321
# (541) 924 - 6902
# aboedigheimer@co.linn.or.us
# POINT (-123.107127 44.635804)
# POINT (-123.107127 44.635804)
# 15
# 8
# 2407
# row-feu8_7est-d269
# Oregon Health & Science University - Isabel McDonald Library
# 505 NW 185th Ave, Beaverton, OR 97006-3499
# Special
# 503-690-5309
# 503-690-5243
# onprclib@ohsu.edu
# POINT (-122.867568 45.52298)
# POINT (-122.867568 45.52298)
# 30
# 15
# 724
# row-8z3g_ykzs-aw42
# Josephine Community Library District - Wolf Creek Branch Library
# 102 Ruth Avenue, Wolf Creek, OR 97497
# Josephine
# Public
# 200 NW C Street, Grants Pass, OR 97526
# 541-866-2606
# NONE
# POINT (-123.39687 42.695344)
# POINT (-123.39687 42.695344)
# 1
# 1
# 2368
# row-9xhy~ru7j.7wik
# University Of Oregon - Institute of Marine Biology Library
# 63466 Boat Basin Drive, Charleston, OR 97420-1221
# Academic
# PO Box 5389, Charleston, OR 97420
# 541-888-2581 X 219
# 541-888-3391
# POINT (-124.328583 43.345474)
# POINT (-124.328583 43.345474)
# 1
# 1
# 2320
# row-min9~fypa.3ngz
# University Of Oregon - Mathematics Library
# 1021 East 13th Ave, Eugene, OR 97403-3914
# Lane
# Academic
# 541-346-3023
# mathlib.uoregon.edu
# POINT (-123.068224 44.045523)
# POINT (-123.068224 44.045523)
# 11
# 6
# 2371
# row-za7x.rxvr.z3jw
# Clatskanie Library District
# 11 Lillich St, Clatskanie, OR 97016
# Columbia
# Public
# PO Box 577, Clatskanie, OR 97016
# (503) 728-3732
# (503) 728-4304
# admin@clatskanielibrary.org
# NONE
# POINT (-123.20213 46.10547)
# POINT (-123.20213 46.10547)
# 31
# 16
# 2319
# row-9bwx_ez4a_xrqk
# Canby Public Library
# 220 NE 2nd Ave, Canby, OR 97013
# Clackamas
# Public
# 220 NE 2nd Ave, Canby, OR 97013
# (503) 266-3394
# (503) 266-1709
# CanbyInfo@lincc.org
# LINCC
# POINT (-122.691769 45.264098)
# POINT (-122.691769 45.264098)
# 39
# 20
# 2317
# row-zynv.dtg6-mw8c
# Oregon Trail Library District - OTLD Boardman Branch
# 200 S Main, Boardman, OR 97818
# Morrow
# Public
# PO Box 849, Boardman, OR 97818
# (541) 481-2665
# (541) 481-2668
# kstreet@otld.org
# NONE
# POINT (-119.700766 45.835036)
# POINT (-119.700766 45.835036)
# 57
# 29
# 722
# row-hjip_v5bt_ehrz
# West Linn Public Library
# 1595 Burns St, West Linn, OR 97068
# Clackamas
# Public
# 1595 Burns St, West Linn, OR 97068
# (503) 656-7853
# (503) 742-8632
# wlref@lincc.org
# LINCC
# POINT (-122.613833 45.367323)
# POINT (-122.613833 45.367323)
# 37
# 19
# 2317
# row-y63n.uvay-i2j3
# Gilliam County Public Library
# 134 S Main, Condon, OR 97823
# Gilliam
# Public
# PO Box 34, Condon, OR 97823
# (541) 384-6052
# (541) 384-6052
# gclibrary@co.gilliam.or.us
# NONE
# POINT (-120.184831 45.237483)
# POINT (-120.184831 45.237483)
# 57
# 29
# 2364
# row-wbkq~tffu_ruan
# Oregon Institute of Technology Libraries - Shaw Historical Library at Oregon Tech
# 3201 Campus Drive, Klamath Falls, OR 97601-8801
# Klamath
# Academic
# Shaw Historical Library, 3201 Campus Drive, Klamath Falls, OR 97601-8801
# (541) 885-1686
# (541) 885-1777
# shawlib@oit.edu
# POINT (-121.782271 42.254213)
# POINT (-121.782271 42.254213)
# 56
# 28
# 2369
# row-35y7.y76w.auw2
# Portland Community College - Rock Creek Campus
# 17705 NW Springville Rd, Building 9 - 2nd FloOR Portland, OR 97229
# Academic
# PO Box 19000, Portland, OR 97280-0990
# 971 722-7413
# 971 722--5318
# https://www.pcc.edu/library/about/people/contact/email-a-librarian/
# POINT (-122.85873 45.563046)
# POINT (-122.85873 45.563046)
# 31
# 16
# 724
# row-wn8i-8z85_f2c4
# Birthingway College of Midwifery, Not Available at this Time
# 4997 Southwest Normandy Place, Beaverton, OR 97005-3635
# Washington
# Academic
# 12113 SE Foster Rd, Portland, OR 97266
# 503-760-3131
# library@birthingway.edu
# POINT (-122.824426 45.483618)
# POINT (-122.824426 45.483618)
# 28
# 14
# 724
# row-cugy.r657-bggf
# Harney County Library
# 80 West D St, Burns, OR 97720
# Harney
# Public
# 80 West  D St, Burns, OR 97720
# (541) 573-6670
# (541) 573-1571
# harneycl@harneycountylibrary.org
# NONE
# POINT (-119.05529 43.592163)
# POINT (-119.05529 43.592163)
# 60
# 30
# 720
# row-9df3_vvuw~2n3e
# Tillamook County Library - Tillamook County Library Bookmobile
# 1716 Third St, Tillamook, OR 97141
# Tillamook
# Public
# NONE
# POINT (-123.846541 45.456324)
# POINT (-123.846541 45.456324)
# 32
# 16
# 2412
# row-u7vf-inji-cxaq
# Jackson County Library Services - Jacksonville Branch Library
# 340 West C Street, Jacksonville, OR 97530
# Jackson
# Public
# PO Box 490, Jacksonville, OR 97530
# (541) 899-1665
# (541) 899-1665
# info@jcls.org
# NONE
# POINT (-122.968684 42.315271)
# POINT (-122.968684 42.315271)
# 5
# 3
# 2367
# row-3388_khqa~f6hi
# Confederated Tribes of Umatilla Library
# Tamastslikt Cultural Institute, 47106 Wildhorse Blvd., Pendleton, OR 97801
# Umatilla
# Tribal
# Tamastslikt Cultural Institute, 47106 Wildhorse Blvd., Pendleton, OR 97801
# (541) 429-7721
# malissa.minthorn@tamastslikt.org
# POINT (-118.664803 45.650663)
# POINT (-118.664803 45.650663)
# 58
# 29
# 2413
# row-x5g7-j86u.nptc
# Blue Mountain Community College
# 2411 NW Carden Ave, Pendleton, OR 97801-1000
# Umatilla
# Academic
# PO Box 100, Pendleton, OR 97801
# 541- 278-5916
# onlinelibrary@bluecc.edu
# POINT (-118.81383 45.675622)
# POINT (-118.81383 45.675622)
# 58
# 29
# 2413
# row-m99x~rqs8_nmf2
# Happy Valley Library
# 13793 SE Sieben Park Way, Happy Valley, OR 97015
# Clackamas
# Public
# 13793 SE Sieben Park Way, Happy Valley, OR 97015
# 503 -783-3456
# library@happyvalleyor.gov
# LINCC
# POINT (-122.513576 45.42204)
# POINT (-122.513576 45.42204)
# 51
# 26
# 2317
# row-4ud6.i5sr_y24z
# Wilsonville Public Library
# 8200 SW Wilsonville Rd, Wilsonville, OR 97070
# Clackamas
# Public
# 8200 SW Wilsonville Rd, Wilsonville, OR 97070
# (503) 682-2744
# (503) 682-8685
# reference@wilsonvillelibrary.org
# LINCC
# POINT (-122.761012 45.302904)
# POINT (-122.761012 45.302904)
# 26
# 13
# 2317
# row-b76a~68hj~53iq
# Deschutes Public Library System - Sisters Library
# 110 N Cedar St, Sisters, OR 97759
# Deschutes
# Public
# PO Box 1209, Sisters, OR 97759
# (541) 312-1070
# (541) 549-9620
# NONE
# POINT (-121.545092 44.291822)
# POINT (-121.545092 44.291822)
# 59
# 30
# 2362
# row-ccth~unxf.2hep
# Independence Public Library
# 175 Monmouth St, Independence, OR 97351
# Polk
# Public
# 175 Monmouth St, Independence, OR 97351
# (503) 838-1811
# (503) 838-4486
# achristensen@ci.independence.or.us
# CCRLS
# POINT (-123.185699 44.851123)
# POINT (-123.185699 44.851123)
# 20
# 10
# 723
# row-mywn_ttix-k7r8
# LINCC Library Services - Network
# 1810 Red Soils Court, #110, Oregon City, OR 97045
# Clackamas
# Public
# 1810 Red Soils Court, #110, Oregon City, OR 97045
# (503) 723-4888
# (503) 655-8238
# contact@lincc.org
# LINCC
# POINT (-122.5949 45.33153)
# POINT (-122.5949 45.33153)
# 40
# 20
# 2317
# row-gd9g-z5fm~aju7
# North Powder City Library
# 290 E St, North Powder, OR 97867
# Union
# Public
# PO Box 309, North Powder, OR 97867
# (541) 898-2175
# (541) 898-2175
# npcitylibrary1@gmail.com
# NONE
# POINT (-117.920729 45.029187)
# POINT (-117.920729 45.029187)
# 58
# 29
# 2414
# row-27k7~vniv_988q
# Hillsboro Public Library - Shute Park Library
# 775 SE Tenth Avenue, Hillsboro, OR 97123
# Washington
# Public
# 775 SE Tenth Avenue, Hillsboro, OR 97123
# (503) 615-6500
# (503) 615-6501
# WCCLS
# POINT (-122.974028 45.514032)
# POINT (-122.974028 45.514032)
# 29
# 15
# 724
# row-jzye~34r6~rihv
# Portland Community College - Southeast Campus
# 2305 S.E. 82nd Ave., Portland, OR 97216
# Multnomah
# Academic
# PO Box 19000, Portland, OR 97289-0900
# (971) 722-6187
# https://www.pcc.edu/library/about/people/contact/email-a-librarian/
# POINT (-122.578728 45.506208)
# POINT (-122.578728 45.506208)
# 46
# 23
# 2410
# row-tcms~d897.p7qi
# Aloha Community Library
# 17455 SW Farmington Rd, Suite 26A, Aloha, OR 97007
# Washington
# Public
# P.O. Box 6561, Aloha, OR 97007
# 503-259-0185
# info@alohalibrary.org
# WCCLS
# POINT (-122.858615 45.479285)
# POINT (-122.858615 45.479285)
# 28
# 14
# 724
# row-cd65-eknm-f7nz
# Junction City Public Library
# 726 Greenwood St, Junction City, OR 97448
# Lane
# Public
# PO Box 280, Junction City, OR 97448
# (541) 998-8942
# (000) 000-0000
# MSchneider@ci.junction-city.or.us
# NONE
# POINT (-123.202607 44.220326)
# POINT (-123.202607 44.220326)
# 14
# 7
# 2371
# row-9ntm_gapk-vb7p
# Linfield University Libraries - Portland Campus Library
# 2255 NW 22nd Ave, Portland, OR 97210
# Academic
# 503-413-7820
# 503-229-8016
# POINT (-122.696926 45.539106)
# POINT (-122.696926 45.539106)
# 33
# 17
# 2410
# row-zjj6.783t-s3vq
# Crook County Library
# 175 NW Meadow Lakes Dr, Prineville, OR 97754
# Crook
# Public
# 175 NW Meadow Lakes Dr, Prineville, OR 97754
# (541) 447-7978
# (541) 447-1308
# library@crooklib.org
# NONE
# POINT (-120.856965 44.301532)
# POINT (-120.856965 44.301532)
# 55
# 28
# 719
# row-brtg~vzt3.ebmi
# Spray Public/School Library
# 303 Park Ave., Spray, OR 97874
# Wheeler
# Public
# PO Box 230, Spray, OR 97874
# (541) 468-2226
# (541) 468-2630
# ljohnson@spray.k12.or.us
# NONE
# POINT (-119.793004 44.833654)
# POINT (-119.793004 44.833654)
# 59
# 30
# 2452

# %%
import json
import codecs

def parseElement(element, classes, entities, properties, literals):

    for key in element.keys():
        if key=="@id":
            entities.append(element[key])
        elif key=="@type":
            classes.append(element[key])
        
        if isinstance(element[key], str):
            literals.append(element[key])
        elif isinstance(element[key], object):
            parseElement(element[key], classes, entities, properties, literals)

        properties.append(key)


def parse_as_JSON(file_path: str):
    json_file = json.load(codecs.open(file_path, "r", "utf-8-sig"), strict=False)
    classes = list()
    entities = list()
    properties = list()
    literals = list()

    graph = json_file["@graph"]

    for element in graph:

        parseElement(element, classes, entities, properties, literals)

    for c in classes:
        print(c)
    for c in entities:
        print(c)
    for c in properties:
        print(c)
    for c in literals:
        print(c)

# %%
parse_as_JSON("/media/manuel/Tesi/Datasets/dataset-15976/ingresos.jsonld",)
# Out:
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# espresup:Ingreso
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/389
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/6916ebeee218d8aed151cbe0dbf5d0fe
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/85
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/10e0b8a56fa85aac5a40e9eeb51d981f
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/22
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/aa2d9dae5f19c0697b1a277fff3bb391
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/39
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/359e18cfb979e70ba89d50386254f184
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/505
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/4cce97f584c073e6fd66ae12a4cbfcd8
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/80020
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/fca207c889dd60bccbf91f8304f7ab49
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/912
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/6bee4d089dfe8151b5d58758bd2e7168
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/602
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/29e952ae3481f0531312ce0b04c9aa45
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/750
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/524ced6819a92c7523c10caf4d1cddfc
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/467
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/5d421fc20b975be99fcdc6e17741130f
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/22002
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/b1b1cb66aaa95a2cb965790a4782b695
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/349
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/95714c91d53a2c55daa3c4f647d597b7
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/599
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/928f30326acba94a7a6e4711bc5c553f
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/27
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/1d04980e3a2c91fd07fb89d63071b990
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/17
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/dfaf31b4cb696bd7ebfa39789f63e0ef
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/82000
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/f288db4994c58827e2494b61f8ac0a22
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/296
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/832e7b94261358f068ef00facdd77df7
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/294
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/607109e81b1bb81d885342fc0da79857
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/91
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/1a81de719a35ecf1c6e2361c1baa33da
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/311
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/a53be1671119ddc96f834fdc0da055e9
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/350
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/fe99c519350382f9cef5562e0ca1032f
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/51
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/38016e56cc99a7d29b1fe7239f89d2c3
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/55
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/6c5e27937c852d23814df733413c488f
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/423
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/3a2af9c16d2da1cbc958f98020cbb666
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/319
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/27e4f44163c53d02690a5d6a521b681b
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/380
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/7cb0e526eb5f1ae47f52061669c7e6ab
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/46
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/244690e6c935c2d6698581bf57221d49
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/42000
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/21c661a215d3c36a8b287819ec172b56
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/82010
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/344
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/03536b2a267903db5550975849dacd95
# ...
# 2017Q4
# 257000.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/e68bb5b4363cd0b562039c6dde26efa6
# 2017
# espresup:Ingreso
# De ejercicios cerrados
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/680
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/0b5a7739de2a62049762df2331400c56
# 2017
# espresup:Ingreso
# Tasas por otros servicios urbanísticos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/323
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/1970a936c7850fc8df9776ebdee21e9e
# 2017
# espresup:Ingreso
# Del exterior
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/49
# 2017Q4
# 12.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8f60ffd48fa7f5f8020e51a9d2228a8a
# 2017
# espresup:Ingreso
# De la Administración General del Estado
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/420
# 2017Q4
# 17744252.72
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/9ab50bbe7f74f9be4d883288767f2d72
# 2017
# espresup:Ingreso
# Impuesto sobre la energía
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/22007
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/3fca6bf5c6ec9e7d9f0d6fe2c983cea4
# 2017
# espresup:Ingreso
# Devolución de depósitos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/840
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/dc89e0ac7b15b78bec9ded79ec927048
# 2017
# espresup:Ingreso
# Otras subvenciones corrientes de la Administración General de la Comunidad Autónoma
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/45080
# 2017Q4
# 2083112.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/6603d1e4d3b4e527365f12724df939f7
# 2017
# espresup:Ingreso
# Transferencias de capital en cumplimiento de convenios suscritos con la Comunidad Autónoma en materia de Servicios Sociales y Políticas de Igualdad
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/75002
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/07206d78aacdb0e65f0ab070eb9f6c80
# 2017
# espresup:Ingreso
# Del Fondo Europeo Agrícola de Garantía (FEAGA)
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/793
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/d20dec7ff51c588262060efe36ada853
# 2017
# espresup:Ingreso
# Recargos del periodo ejecutivo y por declaración extemporánea sin requerimiento previo
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/392
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/9015be807ddd222c5cf93d535d04b971
# 2017
# espresup:Ingreso
# Otros ingresos diversos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/399
# 2017Q4
# 1577805.49
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/cadf298b94fa921fa9037cb6569dbcad
# 2017
# espresup:Ingreso
# De Entidades locales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/506
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/ea585161bb86c8beb873c694e44bc0b0
# 2017
# espresup:Ingreso
# TASAS, PRECIOS PÚBLICOS Y OTROS INGRESOS
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/3
# 2017Q4
# 19517120.53
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/47970c2acf70d42e3920db4c618f990c
# 2017
# espresup:Ingreso
# Del Fondo de Desarrollo Regional
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/491
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/ee407b36cb366b49fbdabd08ae7b570c
# 2017
# espresup:Ingreso
# Tasa de estacionamiento de vehículos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/330
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/f5c9f0be0c7cfadff8d85f71cc69116e
# 2017
# espresup:Ingreso
# De Entidades locales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/80120
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/82a2dc44158566a588fc66f0dbf87548
# 2017
# espresup:Ingreso
# Enajenación de deuda del sector público
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/80
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/a6f31c4889d77e36fcd577e97b793325
# 2017
# espresup:Ingreso
# De Entidades Locales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/76
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8fbfcb9d71feeb43f1d016da8f5319d8
# 2017
# espresup:Ingreso
# IMPUESTOS DIRECTOS
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/1
# 2017Q4
# 76893259.18
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/edc3b72e50baed6d6f819b082223bd97
# 2017
# espresup:Ingreso
# De entes públicos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/440
# 2017Q4
# 6.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/e09a8e898b6be4fc031a46743e9d61ac
# 2017
# espresup:Ingreso
# Beneficios por realización de inversiones financieras
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/591
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/7a16a03aeda6e0990ae09f78d2017b1c
# 2017
# espresup:Ingreso
# De Diputaciones, Consejos o Cabildos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/461
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/3ffae3727ab4f02e2be5210ccdbb56a3
# 2017
# espresup:Ingreso
# De Áreas Metropolitanas
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/464
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8ea8b80effb132194c03cdcf4dc24102
# 2017
# espresup:Ingreso
# Servicio de recogida de basuras
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/302
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/59b3a507289dd520f3d6cb6e85741f31
# 2017
# espresup:Ingreso
# Del Fondo Europeo Agrícola de Garantía (FEAGA)
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/493
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8e44d797bf8ad2e799558a0425189b0d
# 2017
# espresup:Ingreso
# Sobre impuestos de otros entes locales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/270
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/2e962b2f9ba2ca5e6796767751008be6
# 2017
# espresup:Ingreso
# Prestación de transporte
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/395
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/e979f8b7661e73fcf38059d4bfc38980
# 2017
# espresup:Ingreso
# Servicios asistenciales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/341
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/b97ec50c7ab15ec3b317ef3f8311678b
# 2017
# espresup:Ingreso
# Impuesto sobre el alcohol y bebidas derivadas
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/22000
# 2017Q4
# 26494.55
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8c40e9d16064fdbba23b45dd98fb7877
# 2017
# espresup:Ingreso
# Del Fondo Europeo de la Pesca (FEP)
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/496
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/af388f124883a2c9269350757ad5b917
# 2017
# espresup:Ingreso
# Tasa por utilización privativa o aprovechamiento especial por empresas explotadoras de servicios de suministros
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/332
# 2017Q4
# 2300000.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/254e4f16b3c8fa0b73296b836ca206f2
# 2017
# espresup:Ingreso
# De otros Organismos Autónomos y Agencias
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/42190
# 2017Q4
# 12.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/0e9d7b8ace4a33f2c47d60e708deabab
# 2017
# espresup:Ingreso
# Tasa por entrada de vehículos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/331
# 2017Q4
# 1647879.48
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/82123ca24e2397c37105ff939624fdef
# 2017
# espresup:Ingreso
# Impuesto sobre Patrimonio
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/111
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/43001fa2b27d4ba12f83ad22240304b3
# 2017
# espresup:Ingreso
# Otras transferencias del exterior, excluyendo la Unión Europea
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/799
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/4cf4de330166520974b19d17c45ed41d
# 2017
# espresup:Ingreso
# Para gastos generales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/87000
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/f93b5e29fc58a19a6734b22a964adf54
# 2017
# espresup:Ingreso
# Para gastos con financiación afectada
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/87010
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/6a99cffd9757484f82da2d1d5be8e160
# 2017
# espresup:Ingreso
# Del exterior
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/79
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/25c836c221968dfe17195aa7c08fdeb5
# 2017
# espresup:Ingreso
# Servicio de transporte público urbano
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/345
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/7d14432537edd95823a26d51dfacfe71
# 2017
# espresup:Ingreso
# De sociedades y entidades dependientes de las entidades locales
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/53400
# 2017Q4
# 6.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/bfabecf6aba83096807806ce6d6fc941
# 2017
# espresup:Ingreso
# Del Fondo Europeo de la Pesca (FEP)
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/796
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/8df66b4003b5603b35ffd41c1d8b490a
# 2017
# espresup:Ingreso
# De Entidades locales Menores
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/468
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/a62c1dac33b76e74ee4accfc94d2fd5c
# 2017
# espresup:Ingreso
# De la Seguridad Social
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/73
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/0d12a4584aafa1234b82d32e7a4a9220
# 2017
# espresup:Ingreso
# Impuesto sobre las Actividades Económicas
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/13
# 2017Q4
# 9100006.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/c93ca89f43b1c898333af96df60a9839
# 2017
# espresup:Ingreso
# Depósitos y fianzas recibidos
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/94
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/9d7f4d149aa1f805103204b2d86ed889
# 2017
# espresup:Ingreso
# Servicios hospitalarios
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/340
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/e21eb074bf211931275093e54727daa4
# 2017
# espresup:Ingreso
# De fundaciones de las Comunidades Autónomas
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/752
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/3a06fdb1df5197e3a65d03c6307e9d45
# 2017
# espresup:Ingreso
# TRANSFERENCIA CORRIENTES
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/4
# 2017Q4
# 19916113.69
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/4fdd46fcaecb947a712bc86a5edb4091
# 2017
# espresup:Ingreso
# Enajenación de obligaciones y bonos fuera del sector público a largo plazo
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/811
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/16afb4cd2552e8730f7ac9b188ac10ba
# 2017
# espresup:Ingreso
# Enajenación de acciones y participaciones fuera del sector público
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/86
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/2d8c871ea16012935e7ececdbd5c19e0
# 2017
# espresup:Ingreso
# Impuesto sobre la Renta de No Residentes
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/102
# 2017Q4
# 0.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/1393f31fa48df8e3a245667f36bed2d4
# 2017
# espresup:Ingreso
# Otras tasas por utilización privativa del dominio público
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/339
# 2017Q4
# 276923.85
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/28bd4ae9d9893cff59660626c9de5cd1
# 2017
# espresup:Ingreso
# Préstamos recibidos a largo plazo de entes de fuera del sector público
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/913
# 2017Q4
# 6002686.02
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/fb5012af397d34266ae73a15e7341c63
# 2017
# espresup:Ingreso
# Reintegros de operaciones corrientes
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/38
# 2017Q4
# 605000.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/e7175374a9e46668261fe939c041c27b
# 2017
# espresup:Ingreso
# Tasas por aprovechamiento del vuelo
# skos:Concept
# http://datos.localidata.com/api/kos/hacienda/presupuestos/clasificacion-economica-2014/ingresos/337
# 2017Q4
# 28000.00
# http://datos.alcobendas.org/recurso/hacienda/presupuestos/ingreso/5b3941e260d968df618a615eb7c609f0

# %%
import rdflib
from rdflib import Graph 

not_parsable_rdflib = list()

for f in files:

    g = Graph()
    try:
        g.parse(f)
    except Exception:
        not_parsable_rdflib.append(f)
# Out:
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x7ff23000ab00>
# Traceback (most recent call last):
#   File "/home/manuel/.local/lib/python3.10/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/home/manuel/.local/lib/python3.10/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0170'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x7ff23000ab00>
# Traceback (most recent call last):
#   File "/home/manuel/.local/lib/python3.10/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/home/manuel/.local/lib/python3.10/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0185'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x7ff23000ab00>
# Traceback (most recent call last):
#   File "/home/manuel/.local/lib/python3.10/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/home/manuel/.local/lib/python3.10/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0165'
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#gYear, Converter=<function parse_date at 0x7ff23000ab00>
# Traceback (most recent call last):
#   File "/home/manuel/.local/lib/python3.10/site-packages/rdflib/term.py", line 2084, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/home/manuel/.local/lib/python3.10/site-packages/isodate/isodates.py", line 203, in parse_date
#     raise ISO8601Error('Unrecognised ISO 8601 date format: %r' % datestring)
# isodate.isoerror.ISO8601Error: Unrecognised ISO 8601 date format: '-0190'
# file:///media/manuel/Tesi/Datasets/dataset-44849/10TH WARD AUTO SALES does not look like a valid URI, trying to serialize this will break.
# file:///media/manuel/Tesi/Datasets/dataset-44871/18TH STREET DISTILLERY LLC does not look like a valid URI, trying to serialize this will break.

# %%
print(len(files))
print(len(not_parsable_rdflib))
# Out:
# 247
# 125

# %%
print(not_parsable_rdflib)
# Out:
# ['/media/manuel/Tesi/Datasets/dataset-2210/rows.rdf', '/media/manuel/Tesi/Datasets/dataset-2556/rows.rdf', '/media/manuel/Tesi/Datasets/dataset
# %%
not_parsable_rtff = 0
for f in not_parsable_rdflib:
    ext = f.split(".")[-1]
    
    if ext == "jsonld":
        parse_as_JSON(f)

    if ext == "rdf" or ext == "nt":
        parse_as_XML(f)

    else:
        print("ERROR: ", f)
# Out:
# /media/manuel/Tesi/Datasets/dataset-12577/foaf.rdf Exception: argument of type 'cython_function_or_method' is not iterable
# /media/manuel/Tesi/Datasets/dataset-13043/foaf.rdf Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-13357/owl.owl
# /media/manuel/Tesi/Datasets/dataset-13357/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-13357/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-13388/paris.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-13412/owl.owl
# /media/manuel/Tesi/Datasets/dataset-13412/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-13412/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-13583/gold-2010.owl
# ERROR:  /media/manuel/Tesi/Datasets/dataset-13759/owl.owl
# /media/manuel/Tesi/Datasets/dataset-13759/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-13759/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-13796/owl.owl
# /media/manuel/Tesi/Datasets/dataset-13796/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-13796/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-14195/nomisma.ttl
# ERROR:  /media/manuel/Tesi/Datasets/dataset-14603/owl.owl
# /media/manuel/Tesi/Datasets/dataset-14603/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-14603/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-14806/owl.owl
# /media/manuel/Tesi/Datasets/dataset-14806/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-14806/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-14821/gold-2010.owl
# ERROR:  /media/manuel/Tesi/Datasets/dataset-15082/owl.owl
# /media/manuel/Tesi/Datasets/dataset-15082/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-15082/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# ERROR:  /media/manuel/Tesi/Datasets/dataset-15144/void.ttl
# ERROR:  /media/manuel/Tesi/Datasets/dataset-15150/owl.owl
# /media/manuel/Tesi/Datasets/dataset-15150/rdf-schema.rdf Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-15150/22-rdf-syntax-ns.nt Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-15414/paris.nt Exception: File cannot be parsed as XML
# /media/manuel/Tesi/Datasets/dataset-15803/dfe-20data-20september-202011.rdf Exception: File cannot be parsed as XML
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 6
#       3 ext = f.split(".")[-1]
#       5 if ext == "jsonld":
# ----> 6     parse_as_JSON(f)
#       8 if ext == "rdf" or ext == "nt":
#       9     parse_as_XML(f)
#
# NameError: name 'parse_as_JSON' is not defined
